# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Example: Load data from a CSV file
data = pd.read_csv('Results.csv')

# %%
# Display the first few rows of the dataset
data.head()

# Display summary statistics of the dataset
data.describe()
# Out:
#        How do you view her current relationship with the Trailblazer  \
# count                                        1219.000000
# mean                                            2.042658
# std                                             1.324204
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly  romantic  \
# count                                        1219.000000
# mean                                            2.456112
# std                                             1.785363
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly friendly  \
# count                                        1219.000000
# mean                                            2.367514
# std                                             1.268331
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly professional  \
# count                                        1219.000000
# mean                                            3.967186
# std                                             1.567498
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly strangers  \
# count                                        1219.000000
# mean                                            5.254307
# std                                             1.274727
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly enemies  \
# count                                        1219.000000
# mean                                            4.671042
# std                                             1.662660
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        Do you think that the Trailblazer is more of a Self-Insert Character  \
# count                                        1219.000000
# mean                                            5.401969
# std                                             1.938935
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             8.000000
#
#        Do you feel that romantic relationships become the main focus in a story at the expense of other plot points  \
# count                                        1219.000000
# mean                                            4.086136
# std                                             1.520510
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        What do you think of Firefly's visual  \
# count                            1219.000000
# mean                                1.676784
# std                                 1.016551
# min                                 1.000000
# 25%                                 1.000000
# 50%                                 1.000000
# 75%                                 2.000000
# max                                 5.000000
#
#        What do you think of Firefly's personality  \
# count                                 1219.000000
# mean                                     1.768663
# std                                      1.089117
# min                                      1.000000
# 25%                                      1.000000
# 50%                                      1.000000
# 75%                                      2.000000
# max                                      5.000000
#
#        What do you think of Firefly's backstory lore and current place in the story  \
# count                                        1219.000000
# mean                                            1.726825
# std                                             0.936416
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
#
#        How Similar do you think Firefly is to the Trailblazer  \
# count                                        1219.000000
# mean                                            3.474979
# std                                             1.229758
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        How compatible do you think Firefly and Traiblazer are  \
# count                                        1219.000000
# mean                                            2.324856
# std                                             1.581751
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             7.000000
#
#        Was it a disappointment to learn about her true identity as Sam
# count                                        1219.000000
# mean                                            1.962264
# std                                             1.377828
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             5.000000

# %%
len(data['What is your opinion on Firefly'])
# Out:
# 1219

# %%
data['What is your opinion on Firefly'].unique()
# Out:
# array(['I am indifferent', 'I dislike her character',
#        'I like her character', 'She is my favorite character of the game',
#        'She is one of my favorite character',
#        'She is the character I hate the most',
#        'She is one of my most hated character'], dtype=object)

# %%
replacements = {
    "I am indifferent": "indifferent",
    "I dislike her character": "dislike",
    "I like her character": "like",
    "She is my favorite character of the game": "favorite",
    "She is one of my favorite character": "one of favorites",
    "She is the character I hate the most": "hate",
    "She is one of my most hated character": "one of hated"
}

for row_index in range(len(data)):
  value = data["What is your opinion on Firefly"][row_index]
  if value in replacements:
    data.loc[row_index, "What is your opinion on Firefly"] = replacements[value]
    # data["What is your opinion on Firefly"][row_index] = replacements[value]

# %%
data['What is your opinion on Firefly'].unique()
# Out:
# array(['indifferent', 'dislike', 'like', 'favorite', 'one of favorites',
#        'hate', 'one of hated'], dtype=object)

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(data['What is your opinion on Firefly'], kde=True)

# Customize and display the plot
plt.title('What is your opinion on Firefly')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('firefly_opinions.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
data['Do you think she is a good character'].unique()
# Out:
# array(['She is a good character',
#        'Her writing is not over (Expecting more in the future)',
#        'She is average', 'She is a great character',
#        'She is a bad character', 'She is an awful character'],
#       dtype=object)

# %%
replacements = {
    "She is a good character": "good",
    "Her writing is not over (Expecting more in the future)": "incomplete",
    "She is average": "average",
    "She is a great character": "great",
    "She is a bad character": "bad",
    "She is an awful character": "awful"
}

for row_index in range(len(data)):
  value = data["Do you think she is a good character"][row_index]
  if value in replacements:
    data.loc[row_index, "Do you think she is a good character"] = replacements[value]
    # data["Do you think she is a good character"][row_index] = replacements[value]

# %%
data['Do you think she is a good character'].unique()
# Out:
# array(['good', 'incomplete', 'average', 'great', 'bad', 'awful'],
#       dtype=object)

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(data['Do you think she is a good character'], kde=True)

# Customize and display the plot
plt.title('Do you think she is a good character')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('firefly_character_opinions.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
data['How do you view her current relationship with the Trailblazer'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
replacements = {
    1: "I Love it",
    2: "I Love it less",
    3: "Neutral",
    4: "Neutral",
    5: "I Hate it less",
    6: "I Hate it"
}

# df.loc[row_indexer, "col"] = values
for row_index in range(len(data)):
  value = data["How do you view her current relationship with the Trailblazer"][row_index]
  # print(value)
  if value in replacements:
    data.loc[row_index, "How do you view her current relationship with the Trailblazer"] = replacements[value]
    # data["How do you view her current relationship with the Trailblazer"][row_index] = replacements[value]
# Out:
# /tmp/ipykernel_292832/1071801199.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'I Love it' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[row_index, "How do you view her current relationship with the Trailblazer"] = replacements[value]

# %%
data['How do you view her current relationship with the Trailblazer'].unique()
# Out:
# array(['I Love it', 'I Love it less', 'Neutral', 'I Hate it less',
#        'I Hate it'], dtype=object)

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(data['How do you view her current relationship with the Trailblazer'], kde=True)

# Customize and display the plot
plt.title('How do you view her current relationship with the Trailblazer')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('firefly_relationship_opinions.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
data['What is the nature of her relationship with the Traiblazer before they joined the Astral Express'].unique()
# Out:
# array(['Coworker', 'Lovers', 'Strangers', 'Friends', 'Something else',
#        'Enemies'], dtype=object)

# %%
data['What is the nature of her relationship with the Traiblazer now'].unique()
# Out:
# array(['Friends', 'Lovers', 'Coworker', 'Something else', 'Strangers',
#        'Enemies'], dtype=object)

# %%
data['Do you think she is a good character'].unique()
# Out:
# array(['good', 'incomplete', 'average', 'great', 'bad', 'awful'],
#       dtype=object)

# %%
wanted = ['bad', 'awful']

# %%
haters = data[data['Do you think she is a good character'].isin(wanted)]

# %%
non_haters = data[~data['Do you think she is a good character'].isin(wanted)]

# %%
non_haters.describe()
# Out:
#        What would you think if their relationship ended up explicitly  romantic  \
# count                                        1162.000000
# mean                                            2.295181
# std                                             1.659611
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly friendly  \
# count                                        1162.000000
# mean                                            2.298623
# std                                             1.209843
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly professional  \
# count                                        1162.000000
# mean                                            4.031842
# std                                             1.542346
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly strangers  \
# count                                        1162.000000
# mean                                            5.374355
# std                                             1.124527
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly enemies  \
# count                                        1162.000000
# mean                                            4.792599
# std                                             1.580190
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        Do you think that the Trailblazer is more of a Self-Insert Character  \
# count                                        1162.000000
# mean                                            5.428571
# std                                             1.914758
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             8.000000
#
#        Do you feel that romantic relationships become the main focus in a story at the expense of other plot points  \
# count                                        1162.000000
# mean                                            4.117040
# std                                             1.489001
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        What do you think of Firefly's visual  \
# count                            1162.000000
# mean                                1.561962
# std                                 0.872609
# min                                 1.000000
# 25%                                 1.000000
# 50%                                 1.000000
# 75%                                 2.000000
# max                                 5.000000
#
#        What do you think of Firefly's personality  \
# count                                 1162.000000
# mean                                     1.638554
# std                                      0.926308
# min                                      1.000000
# 25%                                      1.000000
# 50%                                      1.000000
# 75%                                      2.000000
# max                                      5.000000
#
#        What do you think of Firefly's backstory lore and current place in the story  \
# count                                        1162.000000
# mean                                            1.622203
# std                                             0.793572
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
#
#        How Similar do you think Firefly is to the Trailblazer  \
# count                                        1162.000000
# mean                                            3.406196
# std                                             1.192958
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        How compatible do you think Firefly and Traiblazer are  \
# count                                        1162.000000
# mean                                            2.152324
# std                                             1.384060
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             7.000000
#
#        Was it a disappointment to learn about her true identity as Sam
# count                                        1162.000000
# mean                                            1.837349
# std                                             1.269892
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000

# %%
haters.describe()
# Out:
#        What would you think if their relationship ended up explicitly  romantic  \
# count                                          57.000000
# mean                                            5.736842
# std                                             0.856202
# min                                             2.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly friendly  \
# count                                          57.000000
# mean                                            3.771930
# std                                             1.592589
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly professional  \
# count                                          57.000000
# mean                                            2.649123
# std                                             1.505837
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly strangers  \
# count                                          57.000000
# mean                                            2.807018
# std                                             1.652256
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        What would you think if their relationship ended up explicitly enemies  \
# count                                          57.000000
# mean                                            2.192982
# std                                             1.342154
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             6.000000
#
#        Do you think that the Trailblazer is more of a Self-Insert Character  \
# count                                          57.000000
# mean                                            4.859649
# std                                             2.333289
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             7.000000
# max                                             8.000000
#
#        Do you feel that romantic relationships become the main focus in a story at the expense of other plot points  \
# count                                          57.000000
# mean                                            3.456140
# std                                             1.973668
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        What do you think of Firefly's visual  \
# count                              57.000000
# mean                                4.017544
# std                                 0.915954
# min                                 1.000000
# 25%                                 3.000000
# 50%                                 4.000000
# 75%                                 5.000000
# max                                 5.000000
#
#        What do you think of Firefly's personality  \
# count                                   57.000000
# mean                                     4.421053
# std                                      0.705776
# min                                      2.000000
# 25%                                      4.000000
# 50%                                      5.000000
# 75%                                      5.000000
# max                                      5.000000
#
#        What do you think of Firefly's backstory lore and current place in the story  \
# count                                          57.000000
# mean                                            3.859649
# std                                             1.076346
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        How Similar do you think Firefly is to the Trailblazer  \
# count                                          57.000000
# mean                                            4.877193
# std                                             1.134998
# min                                             2.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             6.000000
# max                                             6.000000
#
#        How compatible do you think Firefly and Traiblazer are  \
# count                                          57.000000
# mean                                            5.842105
# std                                             1.221671
# min                                             3.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        Was it a disappointment to learn about her true identity as Sam
# count                                          57.000000
# mean                                            4.508772
# std                                             0.965897
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000

# %%
haters['What is the nature of her relationship with the Traiblazer now'].unique()
# Out:
# array(['Friends', 'Strangers', 'Lovers', 'Coworker', 'Something else',
#        'Enemies'], dtype=object)

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(haters['How do you view her current relationship with the Trailblazer'], kde=True)

# Customize and display the plot
plt.title('How do you view her current relationship with the Trailblazer as a hater')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('firefly_relationship_opinions_of_haters.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(non_haters['How do you view her current relationship with the Trailblazer'], kde=True)

# Customize and display the plot
plt.title('How do you view her current relationship with the Trailblazer as a non hater')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('firefly_relationship_opinions_of_non_haters.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(haters['Do you think that the Trailblazer is more of a Self-Insert Character'], kde=True)

# Customize and display the plot
plt.title('Do you think that the Trailblazer is more of a Self-Insert Character as a hater')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('self_insert_opinions_of_haters.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()

# %%
# Increase figure width
plt.figure(figsize=(12, 8))

# Example: Histogram of a specific column
sns.histplot(non_haters['Do you think that the Trailblazer is more of a Self-Insert Character'], kde=True)

# Customize and display the plot
plt.title('Do you think that the Trailblazer is more of a Self-Insert Character as a non hater')
plt.xlabel('Value')
plt.ylabel('Count')

# Rotate labels more and adjust right margin
plt.xticks(rotation=25, ha='right')  # Rotate and right-align for better visibility
plt.subplots_adjust(right=0.9)  # Adjust right margin slightly

# Save the plot as SVG
plt.savefig('self_insert_opinions_of__non_haters.svg', format='svg')  # Replace 'firefly_opinions.svg' with your desired filename
plt.show()
